# %% [markdown]
# ## **Detección condiciones médicas con LLMs**
#
# Qwen 2.5 3B

# %%
#%pip install langchain pymupdf openai openpyxl --quiet

# %%
from typing import List
from pydantic import BaseModel, Field, ValidationError
from langchain.output_parsers import PydanticOutputParser
from langchain.prompts import PromptTemplate
from langchain_core.exceptions import OutputParserException
import requests
import json
import re
from openai import OpenAI
import openai
import httpx
import pandas as pd
import numpy as np
import os
import openpyxl

anotation_file = "C:\\Users\\cpalo\\OneDrive - UPV\\ARA\\2425_ARA\\dataset\\Anotadas.xlsx"

# %% [markdown]
# ## Diabetes

# %%
from datetime import datetime
from typing import Dict, Optional
from pydantic import BaseModel, Field, RootModel 
from langchain_core.exceptions import OutputParserException

class DMDiagnosis(BaseModel):
    DM: int
    Fecha_Dx_DM: Optional[datetime] = Field(None, description="Date of DM diagnosis")

# Root model whose single value is Dict[str, Diagnosis]
class ArgumentResponse(RootModel[Dict[str, DMDiagnosis]]):
    pass

pydantic_parser = PydanticOutputParser(pydantic_object=ArgumentResponse)

def extract_json_block(text: str) -> str:
    """Extract a JSON object from LLM output (robust to markdown and extra text)."""
    match = re.search(r"\{.*\}", text, re.DOTALL)
    if not match:
        raise ValueError(f"Could not find a JSON object in output:\n{text}")
    return match.group(0)

example_json = {
    "38945530.pdf": {
        "DM": 0,
        "Fecha_Dx_DM": "2019-05-21"
    }
}


def extract_arguments_json(text: str, condition: str) -> ArgumentResponse:
    format_instructions = pydantic_parser.get_format_instructions()
    prompt = PromptTemplate(
        template=(
            "You are an medical diagnosis assistant reading patient medical histories in pdfs.\n\n"
            "I want to extract if the patient has Diabetes (DM = 1 if not DM=0) and its date of diagnosis (YYYY-MM-DD) if present.\n\n"
            "Extract pdf name, diagnosis and date ONLY in regard to this specific medical condition: \"{condition}\" directly from the text below.\n\n"
            "Text:\n\"\"\"\n{text}\n\"\"\""
            "Return **exactly one JSON object** whose keys are the PDF file names and whose "
            "values follow this example:\n"
            "   json.dumps(example_json, indent=2)\n\n"
            "{format_instructions}"
            "Do not include markdown (```), explanations, or JSON schemas. Just output the raw JSON object without fields like properties or required."
        ),
        input_variables=["text", "condition"],
        partial_variables={"format_instructions": format_instructions},
    )

    final_prompt = prompt.format_prompt(text=text, condition=condition).to_string()

    payload = {
        "model": "qwen2.5:3b",
        "prompt": final_prompt,
        "temperature": 0,
        "stream": False
    }

    response = requests.post("http://localhost:11434/api/generate", json=payload)
    if response.status_code != 200:
        raise Exception(f"Ollama error: {response.text}")

    raw_output = response.json()["response"]

    print("Model Output:", raw_output)
        # ---- try to parse; on error just return None
    try:
        return pydantic_parser.parse(raw_output)
    
    except OutputParserException as err:
        print("⚠️  Parse failed:", err)
        return None

import json
from datetime import datetime

def write_ndjson(pdf_name: str, diag_dict: dict, path: str = "diagnoses_diabetes.txt"):
    # Convert any datetime objects to ISO strings so json.dumps can handle them
    for k, v in diag_dict.items():
        if isinstance(v, datetime):
            diag_dict[k] = v.date().isoformat()   # "YYYY-MM-DD"

    record = {pdf_name: diag_dict}               # wrap with the filename key
    line = json.dumps(record, ensure_ascii=False)

    # Append to the file, adding a newline
    with open(path, "a", encoding="utf-8") as f:
        f.write(line + "\n")

# %%
len(df[df['Patologia']=='Diabetes'])
# Out:
# 4642

# %%
df['Tipo_Ocurrencia'].unique()
# Out:
# array(['E10', 'Diabetes', 'Diabetes Mellitus', 'N19',
#        'Insuficiencia Renal', 'E13', 'Insuficiencia Renal Cronica',
#        'Hipertension', 'Hipertension esencial', 'Hipertension arterial',
#        'DM', 'I10X', 'ERC', 'HTA', 'Enfermedad Renal Cronica',
#        'Hipertensión', 'Hipertensión arterial', 'E11',
#        'Insuficiencia Renal Crónica'], dtype=object)

# %%
df[df['Patologia']=='Diabetes']['Tipo_Ocurrencia'].unique()
# Out:
# array(['E10', 'Diabetes', 'Diabetes Mellitus', 'E13', 'DM', 'E11'],
#       dtype=object)

# %%
from collections import defaultdict
import difflib                           

pdf_to_snippets: dict[str, list[str]] = defaultdict(list)

for key in x_test.keys():               
    pdf_name, _ = key.rsplit("_", 1)
    if x_test[key]['Patologia'] == 'Diabetes':   
        pdf_to_snippets[pdf_name].append(x_test[key]["Contexto_recuperado"])

def deduplicate(snippets: list[str], similarity=0.85) -> list[str]:
    kept: list[str] = []
    for s in snippets:
        duplicate = False
        for t in kept:
            if s in t or t in s:                  # exact / containment
                duplicate = True
                break
            if difflib.SequenceMatcher(None, s, t).quick_ratio() >= similarity:
                duplicate = True                  # high overlap
                break
        if not duplicate:
            kept.append(s)
    return kept

pdf_to_text: dict[str, str] = {
    pdf: "\n".join(deduplicate(snips))
    for pdf, snips in pdf_to_snippets.items()
}

print("Number of PDFs with diabetes snippets:", len(pdf_to_text))
pdf_to_text
# Out:
# Number of PDFs with diabetes snippets: 85
# {'CC38990979.pdf': '2019 00 50 11 01 2019 14 00 Urgencias Hospitalizacion No R104 OTROS DOLORES ABDOMINALES Y LOS NO ESPECIFICADOS 20 03 2019 13 21 20 03 2019 13 36 Ambulatoria E109 DIABETES MELLITUS INSULINODEPENDIE NTE SIN MENCION DE COMPLICACION 21 06 2019 13 15 21 06 2019 13 48 Ambulatoria ENFERMEDAD GENERAL E109 DIABETES MELLITUS INSULINODEPENDIE NTE SIN MENCION DE COMPLICACION\n15 03 2021 09 32 Ambulatoria ENFERMEDAD GENERAL E108 DIABETES MELLITUS INSULINODEPENDIE NTE CON COMPLICACIONES NO ESPECIFICADAS 07 04 2021 16 02 07 04 2021 16 22 Ambulatoria ENFERMEDAD GENERAL E136 DIABETES MELLITUS ESPECIFICADA CON OTRAS COMPLICACIONES ESPECIFICADAS Fecha de ingreso Fecha de egreso Tipo de atención Causa externa Diagnóstico principal Si No 07 07 2021 15 32 07 07 2021\n2021 15 32 07 07 2021 15 47 Ambulatoria ENFERMEDAD GENERAL E136 DIABETES MELLITUS ESPECIFICADA CON OTRAS COMPLICACIONES ESPECIFICADAS 15 07 2021 09 54 15 07 2021 09 55 Ambulatoria E136 DIABETES MELLITUS ESPECIFICADA CON OTRAS COMPLICACIONES ESPECIFICADAS 19 07 2021 07 55 19 07 2021 07 56 Ambulatoria ENFERMEDAD GENERAL N19X INSUFICIENCIA RENAL NO ESPECIFICADA 11 08 2021 14 42\n07 01 2022 13 40 Ambulatoria ENFERMEDAD GENERAL E109 DIABETES MELLITUS INSULINODEPENDIE NTE SIN MENCION DE COMPLICACION 07 01 2022 14 25 07 01 2022 14 47 Ambulatoria ENFERMEDAD GENERAL E108 DIABETES MELLITUS INSULINODEPENDIE NTE CON COMPLICACIONES NO ESPECIFICADAS 07 04 2022 10 48 07 04 2022 11 16 Ambulatoria ENFERMEDAD GENERAL E109 DIABETES MELLITUS INSULINODEPENDIE NTE SIN MENCION DE COMPLICAC
EBE ASISTIR CUMPLIDAMENTE A SUS CITAS DE CONTROL Y SER ADHERENTE A SU TRATAMIENTO FARMACOLÓGICO Y NO FARMACOLÓGICO\nCON LOSARTAN NO SINROMATOLOGIA CARDIOVASCULAR NO EDEMAS NO MAREO NO CEFALEA NO CONSULTAS EN URGENCIAS NI HOSPITALIZACIONES RECIENTES DIAGNOSTICOS HIPERTENSION ARTERIAL 1990 ENFERMEDAD RENAL CRONICA GRADO 3B A1 DISLIPIDEMIA PREDIABETES DX MARZO 2022 TRATAMIERNTO LOSARTAN 50 MG 3 HCTZ 25 MG 1 PARACLINICDOS 20 05 2023 REVISIÓN POR SISTEMAS Sistema neurológico Normal Sistema cardiovascular Normal Tórax y sistema respiratorio Normal',
#  'CC29210651.pdf': '500 MG DIARIO Firmado por DAYANA ISABEL TERAN CAMARGO MEDICINA GENERAL Registro 76078896 OTRAS NOTAS Fecha 18 01 2024 07 23 Ambulatoria Ubicación CENTRAL DE RIESGO Nota de auditoría ADMINISTRATIVO Observaciones paciente ya esta en el programa ximena Firmado por APRENDIZ RCV 02 ADMINISTRATIVO Registro 12345678 COOSALUD ENTIDAD PROMOTORA DE NOTAS MÉDICAS 06 10 2023 Antecedentes actualizados en el sistema\n75 A veces 0 50 Normalmente 0 25 Siempre 0 Puntuación 8 Alta adherencia Puntuación 6 7 Adherencia media Puntuación lt 6 Baja adherencia TEST DE BATALLA Qué es la DM una enfermedad para toda la vida NO Se puede controlar con dieta y medicación SI Mencione 2 o más órganos que pueden dañarse por la glucosa elevada CORAZON RIÑONES REVISIÓN\n02 EN SEGUIMIENTO CON NEFROLOGIA PENDIENTE CONTROL EN HUV MAÑANA SE REFUERZAN MEDIDAS DE NEFROPROTECCION APORTA NUEVOS EXAMENES DE CONTROL CON LDL EN METAS PERFIL GLICEMICO EN RANGO DE PREDIABETES POR LO CUAL SE REFUERZA ALIMENTACION POTASIO EN METAS TSH NORMLA SODIO NORMAL POR EL MOMENTO INDICO CONTINUAR CON TRATAMIENTO MEIDCO Plan de manejo LOSARTAN 50 MG DIARIO CARVEDILOL 6',
#  'CC6082929.pdf': 'LEVOTIROXINA 50 DIARIO Firmado por DAYANA ISABEL TERAN CAMARGO MEDICINA GENERAL Registro 76078896 OTRAS NOTAS Fecha 18 01 2024 08 00 Ambulatoria Ubicación CENTRAL DE RIESGO Nota de auditoría ADMINISTRATIVO Observaciones pcte ya esta en el programa ximena Firmado por APRENDIZ RCV 02 ADMINISTRATIVO Registro 12345678 COOSALUD ENTIDAD PROMOTORA DE NOTAS MÉDICAS Antecedentes actualizados en el sistema para la fecha'}

# %%
for i, (pdf_name, merged_text) in enumerate(pdf_to_text.items(), start=1):
    print(len(merged_text.split()), "tokens in", pdf_name)
# Out:
# 1343 tokens in CC38990979.pdf
# 915 tokens in CC21376431.pdf
# 732 tokens in CC2392028.pdf
# 974 tokens in CC66811116.pdf
# 183 tokens in CC4640234.pdf
# 366 tokens in CC94281430.pdf
# 958 tokens in CC31260873.pdf
    if i % 10 == 0:
        print(f"Registro: {i} de {len(pdf_to_text)}")

    prompt_text = f"pdf name: {pdf_name}\n{merged_text}"
    result = extract_arguments_json(prompt_text, condition)

    if result is None or len(result.root)==0:  
        continue

    diag = next(iter(result.root.values()))         
    write_ndjson(
        pdf_name,                                  
        {"DM": diag.DM, "Fecha_Dx_DM": diag.Fecha_Dx_DM},
        path=out_path,
    )
# Out:
# Model Output: {
#   "CC38990979.pdf": {
#     "DM": 1,
#     "Fecha_Dx_DM": null
#   }
# }
# Model Output: {
#     "CC21376431.pdf": {
#         "DM": 0,
#         "Fecha_Dx_DM": null
#     }
# }
# Model Output: {"CC2392028.pdf": {"DM": 1, "Fecha_Dx_DM": null}}
# Model Output: {"CC66811116.pdf": {"DM": 0, "Fecha_Dx_DM": null}}
# Model Output: {"CC4640234.pdf": {"DM": 1, "Fecha_Dx_DM": null}}
# Model Output: {"CC94281430.pdf": {"DM": 0, "Fecha_Dx_DM": null}}
# Model Output: {"CC31260873.pdf": {"DM": 0, "Fecha_Dx_DM": null}}
# Model Output: {"CC38440317.pdf": {"DM": 1, "Fecha_Dx_DM": "2019-03-28"}}
# Model Output: {"CC29802554.pdf": {"DM": 1, "Fecha_Dx_DM": null}, "COXARTROSIS_NO_ESPECIFICADA.pdf": {"DM": 0, "Fecha_Dx_DM": null}}
# Registro: 10 de 85
# Model Output: {"CC29325288.pdf": {"DM": 0, "Fecha_Dx_DM": null}}
# Model Output: {"CC31252756.pdf": {"DM": 0, "Fecha_Dx_DM": null}}
# Model Output: {"CC41306363.pdf": {"DM": 0, "Fecha_Dx_DM": null}}
# Model Output: {"CC2550458.pdf": {"DM": 1, "Fecha_Dx_DM": null}}
# Model Output: {"CC31219907.pdf": {"DM": 0, "Fecha_Dx_DM": null}}
# Model Output: {"CC38960494.pdf": {"DM": 0, "Fecha_Dx_DM": null}}
# Model Output: {"DM6494067.pdf": {"DM": 0, "Fecha_Dx_DM": null}}
# Model Output: {"CC4589307.pdf": {"DM": 1, "Fecha_Dx_DM": null}}
# Model Output: {"CC29298149.pdf": {"DM": 0}}
# Model Output: {"CC14986444.pdf": {"DM": 0, "Fecha_Dx_DM": null}}
# Registro: 20 de 85
# Model Output: {"CC24268447.pdf": {"DM": 0, "Fecha_Dx_DM": null}}
# Model Output: {"CC26390865.pdf": {"DM": 0, "Fecha_Dx_DM": null}}
# Model Output: {"CC14994724.pdf": {"DM": 0, "Fecha_Dx_DM": null}}
# Model Output: {"CC6256890.pdf": {"DM": 1, "Fecha_Dx_DM": null}}
# Model Output: {"CC31239230.pdf": {"DM": 0, "Fecha_Dx_DM": null}}
# Model Output: {"CC25264743.pdf": {"DM": 0, "Fecha_Dx_DM": null}}
# Model Output: {"CC6086951.pdf": {"DM": 0, "Fecha_Dx_DM": null}}
# Model Output: {"CC31889024.pdf": {"DM": 0, "Fecha_Dx_DM": null}}
# Model Output: {"CC31236581.pdf": {"DM": 0, "Fecha_Dx_DM": null}}
# Model Output: {"CC66975500.pdf": {"DM": 0, "Fecha_Dx_DM": null}}
# Registro: 30 de 85
# Model Output: {"CC29804260.pdf": {"DM": 0, "Fecha_Dx_DM": null}}
# Model Output: {"CC27322738.pdf": {"DM": 0, "Fecha_Dx_DM": null}}
# Model Output: {"CC66846793.pdf": {"DM": 0, "Fecha_Dx_DM": null}}
# Model Output: {"CC31988364.pdf": {"DM": 0, "Fecha_Dx_DM": null}}
# Model Output: {"CC41377296.pdf": {"DM": 0, "Fecha_Dx_DM": null}}
# Model Output: {"CC6085419.pdf": {"DM": 0, "Fecha_Dx_DM": null}}
# Model Output: {"CC27508135.pdf": {"DM": 0, "Fecha_Dx_DM": null}}
# Model Output: {"CC34532892.pdf": {"DM": 1, "Fecha_Dx_DM": null}}
# Model Output: {"CC16679174.pdf": {"DM": 0, "Fecha_Dx_DM": null}}
# Model Output: {"CC31253879.pdf": {"DM": 0, "Fecha_Dx_DM": null}}
# Registro: 40 de 85
# Model Output: {"CC14870542.pdf": {"DM": 0, "Fecha_Dx_DM": null}}
# Model Output: {"CC29768571.pdf": {"DM": 0, "Fecha_Dx_DM": null}}
# Model Output: {"CC29938688.pdf": {"DM": 0, "Fecha_Dx_DM": null}}
# Model Output: {"CentralRiesgo1806543297": {"DM": 2, "Fecha_Dx_DM": "2018-04-02T00:00:00Z"}, "DerechosHumanos1806543304": null, "MedicinaInterna1806543784": {"DM": 2, "Fecha_Dx_DM": "2018-04-02T00:00:00Z"}, "Optometria1806543592": null}
# ⚠️  Parse failed: Failed to parse ArgumentResponse from completion {"CentralRiesgo1806543297": {"DM": 2, "Fecha_Dx_DM": "2018-04-02T00:00:00Z"}, "DerechosHumanos1806543304": null, "MedicinaInterna1806543784": {"DM": 2, "Fecha_Dx_DM": "2018-04-02T00:00:00Z"}, "Optometria1806543592": null}. Got: 2 validation errors for ArgumentResponse
# DerechosHumanos1806543304
#   Input should be a valid dictionary or instance of DMDiagnosis [type=model_type, input_value=None, input_type=NoneType]
#     For further information visit https://errors.pydantic.dev/2.11/v/model_type
# Optometria1806543592
#   Input should be a valid dictionary or instance of DMDiagnosis [type=model_type, input_value=None, input_type=NoneType]
#     For further information visit https://errors.pydantic.dev/2.11/v/model_type
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/OUTPUT_PARSING_FAILURE
# Model Output: {"CC29013852.pdf": {"DM": 0, "Fecha_Dx_DM": null}}
# Model Output: {"CC25668921.pdf": {"DM": 0, "Fecha_Dx_DM": null}}
# Model Output: {"CC38431259.pdf": {"DM": 0, "Fecha_Dx_DM": null}}
# Model Output: {"CC24117336.pdf": {"DM": 0, "Fecha_Dx_DM": null}}
# Model Output: {"CC16618290.pdf": {"DM": 0, "Fecha_Dx_DM": null}}
# Model Output: {"CC7425344.pdf": {"DM": 0, "Fecha_Dx_DM": null}}
# Registro: 50 de 85
# Model Output: {"CC29420074.pdf": {"DM": 1, "Fecha_Dx_DM": null}}
# Model Output: {"CC29218414.pdf": {"DM": 0, "Fecha_Dx_DM": null}}
# Model Output: {"CC38994135.pdf": {"DMDiagnosis": 0}}
# ⚠️  Parse failed: Failed to parse ArgumentResponse from completion {"CC38994135.pdf": {"DMDiagnosis": 0}}. Got: 1 validation error for ArgumentResponse
# `CC38994135.pdf`.DM
#   Field required [type=missing, input_value={'DMDiagnosis': 0}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/OUTPUT_PARSING_FAILURE
# Model Output: {"CC31245829.pdf": {"DM": 0, "Fecha_Dx_DM": null}}
# Model Output: {"CC1382634.pdf": {"DM": 0, "Fecha_Dx_DM": null}}
# Model Output: {"CC14441265.pdf": {"DM": 0, "Fecha_Dx_DM": null}, "E027839.pdf": {"DM": 1, "Fecha_Dx_DM": "2020-10-06"}}
# Model Output: {"CC1111789238.pdf": {"DM": 0, "Fecha_Dx_DM": null}}
# Model Output: {"CC29569552.pdf": {"DM": 0, "Fecha_Dx_DM": null}}
# Model Output: {"CC38566209.pdf": {"DM": 1, "Fecha_Dx_DM": null}}
# Model Output: {"CC31297039.pdf": {"DM": 0, "Fecha_Dx_DM": null}}
# Registro: 60 de 85
# Model Output: {"CC28902606.pdf": {"DM": 1, "Fecha_Dx_DM": null}}
# Model Output: {"CC29071098.pdf": {"DM": 0, "Fecha_Dx_DM": null}}
# Model Output: {"CC31234612.pdf": {"DM": 0, "Fecha_Dx_DM": null}}
# Model Output: {"CC14981373.pdf": {"DM": 0, "Fecha_Dx_DM": null}}
# Model Output: {"CC34534214.pdf": {"DM": 0, "Fecha_Dx_DM": null}}
# Model Output: {"CC31215428.pdf": {"DM": 0, "Fecha_Dx_DM": "null"}}
# ⚠️  Parse failed: Failed to parse ArgumentResponse from completion {"CC31215428.pdf": {"DM": 0, "Fecha_Dx_DM": "null"}}. Got: 1 validation error for ArgumentResponse
# `CC31215428.pdf`.Fecha_Dx_DM
#   Input should be a valid datetime or date, input is too short [type=datetime_from_date_parsing, input_value='null', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.11/v/datetime_from_date_parsing
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/OUTPUT_PARSING_FAILURE
# Model Output: {"CC334534214.pdf": {"DM": 0, "Fecha_Dx_DM": null}}
# Model Output: {"CC29015033.pdf": {"DM": 0, "Fecha_Dx_DM": null}}
# Model Output: {"CC29569898.pdf": {"DM": 0, "Fecha_Dx_DM": null}}
# Model Output: {"CC28945543.pdf": {"DM": 0, "Fecha_Dx_DM": null}}
# Registro: 70 de 85
# Model Output: {"CC16635483.pdf": {"DM": 0, "Fecha_Dx_DM": null}, "N16724945.pdf": {"DM": 1, "Fecha_Dx_DM": "2019-10-09"}}
# Model Output: {"DM155193.pdf": {"DM": 0, "Fecha_Dx_DM": null}}
# Model Output: {"CC31883054.pdf": {"DM": 0, "Fecha_Dx_DM": null}}
# Model Output: {"CC33123121.pdf": {"DM": 0, "Fecha_Dx_DM": null}}
# Model Output: {"CC1114731025.pdf": {"DM": 0, "Fecha_Dx_DM": null}}
# Model Output: {
#     "CC10550360.pdf": {
#         "DM": 1,
#         "Fecha_Dx_DM": null
#     }
# }
# Model Output: {"CC3288014.pdf": {"DM": 0, "Fecha_Dx_DM": null}}
# Model Output: {"CC29398754.pdf": {"DM": 0}}
# Model Output: {"CC29363141.pdf": {"DM": 0, "Fecha_Dx_DM": null}}
# Model Output: {
#   "CC24444308.pdf": {
#     "DM": 1,
#     "Fecha_Dx_DM": null
#   }
# }
# Registro: 80 de 85
# Model Output: {"CC31242769.pdf": {"DM": 0, "Fecha_Dx_DM": null}}
# Model Output: {"CC38968684.pdf": {"DM": 0, "Fecha_Dx_DM": null}}
# Model Output: {"CC25711801.pdf": {"DM": 0, "Fecha_Dx_DM": null}}
# Model Output: {"CC29141113.pdf": {"DM": 0, "Fecha_Dx_DM": null}}
# Model Output: {"CC29210651.pdf": {"DM": 0, "Fecha_Dx_DM": null}}
# Model Output: {"CC6082929.pdf": {"DM": 0, "Fecha_Dx_DM": null}}

# %% [markdown]
# ### Enfermedad Renal Crónica

# %%
from datetime import datetime
from typing import Dict, Optional
from pydantic import BaseModel, Field, RootModel 

class ERCDiagnosis(BaseModel):
    ERC: int
    Fecha_Dx_ERC: Optional[datetime] = Field(None, description="Date of ERC diagnosis")

# Root model whose single value is Dict[str, Diagnosis]
class ArgumentResponse(RootModel[Dict[str, ERCDiagnosis]]):
    pass

pydantic_parser = PydanticOutputParser(pydantic_object=ArgumentResponse)

def extract_json_block(text: str) -> str:
    """Extract a JSON object from LLM output (robust to markdown and extra text)."""
    match = re.search(r"\{.*\}", text, re.DOTALL)
    if not match:
        raise ValueError(f"Could not find a JSON object in output:\n{text}")
    return match.group(0)


def extract_arguments_json(text: str, condition: str) -> ArgumentResponse:
    format_instructions = pydantic_parser.get_format_instructions()
    prompt = PromptTemplate(
        template=(
            "You are an medical diagnosis assistant reading patient medical histories in pdfs.\n\n"
            "I want to extract if the patient has {condition} (ERC = 1 if not ERC=0) and its date of diagnosis (YYYY-MM-DD) if present.\n\n"
            "Extract pdf name, diagnosis and date ONLY in regard to this specific medical condition: \"{condition}\" directly from the text below.\n\n"
            "Text:\n\"\"\"\n{text}\n\"\"\""
            "Return **exactly one JSON object** whose keys are the PDF file names and whose values follow this format: "
            "{format_instructions}"
            "Do not include markdown (```), explanations, or JSON schemas. Just output the raw JSON object without fields like properties or required."
        ),
        input_variables=["text", "condition"],
        partial_variables={"format_instructions": format_instructions},
    )

    final_prompt = prompt.format_prompt(text=text, condition=condition).to_string()

    payload = {
        "model": "qwen2.5:3b",
        "prompt": final_prompt,
        "temperature": 0,
        "stream": False
    }

    response = requests.post("http://localhost:11434/api/generate", json=payload)
    if response.status_code != 200:
        raise Exception(f"Ollama error: {response.text}")

    raw_output = response.json()["response"]
    print("Model Output:", raw_output)
    try:
        return pydantic_parser.parse(raw_output)
    
    except OutputParserException as err:
        print("⚠️  Parse failed:", err)
        return None

import json
from datetime import datetime

def write_ndjson(pdf_name: str, diag_dict: dict, path: str = "diagnoses_ERC.txt"):
    # Convert any datetime objects to ISO strings so json.dumps can handle them
    for k, v in diag_dict.items():
        if isinstance(v, datetime):
            diag_dict[k] = v.date().isoformat()   # "YYYY-MM-DD"

    record = {pdf_name: diag_dict}               # wrap with the filename key
    line = json.dumps(record, ensure_ascii=False)

    # Append to the file, adding a newline
    with open(path, "a", encoding="utf-8") as f:
        f.write(line + "\n")

def deduplicate(snippets: list[str], similarity=0.85) -> list[str]:
    kept: list[str] = []
    for s in snippets:
        duplicate = False
        for t in kept:
            if s in t or t in s:                  # exact / containment
                duplicate = True
                break
            if difflib.SequenceMatcher(None, s, t).quick_ratio() >= similarity:
                duplicate = True                  # high overlap
                break
        if not duplicate:
            kept.append(s)
    return kept

# %%
df[df['Patologia']=='Enfermedad Renal Crónica']['Tipo_Ocurrencia'].unique()
# Out:
# array(['N19', 'Insuficiencia Renal', 'Insuficiencia Renal Cronica', 'ERC',
#        'Enfermedad Renal Cronica', 'Insuficiencia Renal Crónica'],
#       dtype=object)

# %%
len(df[df['Patologia']=='Enfermedad Renal Crónica'])
# Out:
# 9948

# %%
from collections import defaultdict
import difflib                           

pdf_to_snippets: dict[str, list[str]] = defaultdict(list)

for key in x_test.keys():               
    pdf_name, _ = key.rsplit("_", 1)
    if x_test[key]['Patologia'] == 'Enfermedad Renal Crónica':   
        pdf_to_snippets[pdf_name].append(x_test[key]["Contexto_recuperado"])

pdf_to_text: dict[str, str] = {
    pdf: "\n".join(deduplicate(snips))
    for pdf, snips in pdf_to_snippets.items()
}

print("Number of PDFs with ERC snippets:", len(pdf_to_text))


condition = "Enfermedad Renal Cronica (ERC) or Chronic Kidney Disease or Insuficiencia Renal or N19 "
out_path  = "diagnoses_ERC_qwen2-5_3b_wholetext.txt"

list(pdf_to_text.keys())
# Out:
# Number of PDFs with ERC snippets: 100
# ['CC38990979.pdf',
#  'CC4302926.pdf',
#  'CC21376431.pdf',
#  'CC2392028.pdf',
#  'CC66811116.pdf',
#  'CC27293711.pdf',
#  'CC4640234.pdf',
#  'CC94281430.pdf',
#  'CC31260873.pdf',
#  'CC38440317.pdf',
#  'CC29802554.pdf',
#  'CC29325288.pdf',
#  'CC31252756.pdf',
#  'CC29049220.pdf',
#  'CC41306363.pdf',
#  'CC2550458.pdf',
#  'CC31219907.pdf',
#  'CC38960494.pdf',
#  'CC6494067.pdf',
#  'CC4589307.pdf',
#  'CC29298149.pdf',
#  'CC14986444.pdf',
#  'CC6279058.pdf',
#  'CC24268447.pdf',
#  'CC26390865.pdf',
#  'CC14994724.pdf',
#  'CC6256890.pdf',
#  'CC31239230.pdf',
#  'CC25264743.pdf',
#  'CC6086951.pdf',
#  'CC31889024.pdf',
#  'CC31236581.pdf',
#  'CC66975500.pdf',
#  'CC29804260.pdf',
#  'CC27322738.pdf',
#  'CC66846793.pdf',
#  'CC1232518.pdf',
#  'CC31988364.pdf',
#  'CC38433864.pdf',
#  'CC41377296.pdf',
#  'CC29061348.pdf',
#  'CC6085419.pdf',
#  'CC14438430.pdf',
#  'CC27508135.pdf',
#  'CC31856748.pdf',
#  'CC34532892.pdf',
#  'CC16679174.pdf',
#  'CC31253879.pdf',
#  'CC14870542.pdf',
#  'CC29768571.pdf',
#  'CC29938688.pdf',
#  'CC29408150.pdf',
#  'CC29013852.pdf',
#  'CC25668921.pdf',
#  'CC38431259.pdf',
#  'CC2578511.pdf',
#  'CC24117336.pdf',
#  'CC16618290.pdf',
#  'CC7425344.pdf',
#  'CC29420074.pdf',
#  'CC29218414.pdf',
#  'CC38994135.pdf',
#  'CC31245829.pdf',
#  'CC1382634.pdf',
#  'CC14441265.pdf',
#  'CC1111789238.pdf',
#  'CC29569552.pdf',
#  'CC38566209.pdf',
#  'CC31297039.pdf',
#  'CC28902606.pdf',
#  'CC29071098.pdf',
#  'CC31234612.pdf',
#  'CC14981373.pdf',
#  'CC34534214.pdf',
#  'CC31215428.pdf',
#  'CC6052364.pdf',
#  'CC334534214.pdf',
#  'CC29057853.pdf',
#  'CC16583376.pdf',
#  'CC29015033.pdf',
#  'CC29569898.pdf',
#  'CC28945543.pdf',
#  'CC16693057.pdf',
#  'CC6556408.pdf',
#  'CC16635483.pdf',
#  'CC155193.pdf',
#  'CC31883054.pdf',
#  'CC33123121.pdf',
#  'CC1114731025.pdf',
#  'CC10550360.pdf',
#  'CC3288014.pdf',
#  'CC29398754.pdf',
#  'CC29363141.pdf',
#  'CC24444308.pdf',
#  'CC31242769.pdf',
#  'CC38968684.pdf',
#  'CC25711801.pdf',
#  'CC29141113.pdf',
#  'CC29210651.pdf',
#  'CC6082929.pdf']

# %%
from collections import defaultdict
import difflib                           

pdf_to_snippets: dict[str, list[str]] = defaultdict(list)

for key in x_test.keys():               
    pdf_name, _ = key.rsplit("_", 1)
    if x_test[key]['Patologia'] == 'Enfermedad Renal Crónica':   
        pdf_to_snippets[pdf_name].append(x_test[key]["Contexto_recuperado"])

pdf_to_text: dict[str, str] = {
    pdf: "\n".join(deduplicate(snips))
    for pdf, snips in pdf_to_snippets.items()
}

print("Number of PDFs with ERC snippets:", len(pdf_to_text))


condition = "Enfermedad Renal Cronica (ERC) or Chronic Kidney Disease or Insuficiencia Renal or N19 "
out_path  = "diagnoses_ERC_qwen2-5_3b_wholetext.txt"

for i, (pdf_name, merged_text) in enumerate(pdf_to_text.items(), start=1):
    if i % 10 == 0:
        print(f"Registro: {i} de {len(pdf_to_text)}")

    prompt_text = f"pdf name: {pdf_name} \n text: {merged_text}"
    result = extract_arguments_json(prompt_text, condition)

    if result is None or len(result.root)==0:  
        continue

    diag = next(iter(result.root.values()))         
    write_ndjson(
        pdf_name,                                  
        {"ERC": diag.ERC, "Fecha_Dx_ERC": diag.Fecha_Dx_ERC},
        path=out_path,
    )
# Out:
# Number of PDFs with ERC snippets: 100
# Model Output: {"CC38990979.pdf": {"ERC": 1, "Fecha_Dx_ERC": null}}
# Model Output: {"C4B870F1528B469FB3B79396EB9AFCF7": {"ERC": 3, "Fecha_Dx_ERC": null}, "B5F44BF8BA5D4C4FBE1E7F55DF5FE405": {"ERC": 4, "Fecha_Dx_ERC": null}}
# Model Output: {"CC21376431.pdf": {"ERC": 0, "Fecha_Dx_ERC": null}}
# Model Output: {
#   "CC2392028.pdf": {
#     "ERCDiagnosis": null
#   }
# }
# ⚠️  Parse failed: Failed to parse ArgumentResponse from completion {"CC2392028.pdf": {"ERCDiagnosis": null}}. Got: 1 validation error for ArgumentResponse
# `CC2392028.pdf`.ERC
#   Field required [type=missing, input_value={'ERCDiagnosis': None}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/OUTPUT_PARSING_FAILURE
# Model Output: {"CC66811116.pdf": {"ERC": 0, "Fecha_Dx_ERC": null}}
# Model Output: {"CC27293711.pdf": {"ERC": 0, "Fecha_Dx_ERC": null}}
# Model Output: {"CC4640234.pdf": {"ERC": 1, "Fecha_Dx_ERC": null}}
# Model Output: {"CC94281430.pdf": {"ERC": 0, "Fecha_Dx_ERC": null}}
# Model Output: {"I10X HIPERTENSION ESENCIAL PRIMARIA": {"ERC": 28052019, "Fecha_Dx_ERC": null}, "N189 INSUFICIENCIA RENAL CRONICA NO ESPECIFICADA": {"ERC": 28082020, "Fecha_Dx_ERC": null}}
# Registro: 10 de 100
# Model Output: {"CC38440317.pdf": {"ERC": 0, "Fecha_Dx_ERC": null}}
# Model Output: {"907106 UROANÁLISIS": {"ERC": 3, "Fecha_Dx_ERC": null}, "INTERCONSULTA CONSULTA DE PRIMERA VEZ POR ESPECIALISTA EN NEFROLOGiA": {"ERC": 3}}
# Model Output: {"CC29325288.pdf": {"ERC": 0, "Fecha_Dx_ERC": null}}
# Model Output: {"CC31252756.pdf": {"ERC": 0, "Fecha_Dx_ERC": null}}
# Model Output: {"CC29049220.pdf": {"ERC": 1, "Fecha_Dx_ERC": null}}
# Model Output: {"CC41306363.pdf": {"ERC": 1, "Fecha_Dx_ERC": null}}
# Model Output: {"CC2550458.pdf": {"ERC": 1, "Fecha_Dx_ERC": null}}
# Model Output: {"902783": {"Fecha_Dx_ERC": null}, "1047391243": {"ERC": 15, "Fecha_Dx_ERC": null}, "1144107673": {"Fecha_Dx_ERC": null}}
# ⚠️  Parse failed: Failed to parse ArgumentResponse from completion {"902783": {"Fecha_Dx_ERC": null}, "1047391243": {"ERC": 15, "Fecha_Dx_ERC": null}, "1144107673": {"Fecha_Dx_ERC": null}}. Got: 2 validation errors for ArgumentResponse
# 902783.ERC
#   Field required [type=missing, input_value={'Fecha_Dx_ERC': None}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# 1144107673.ERC
#   Field required [type=missing, input_value={'Fecha_Dx_ERC': None}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/OUTPUT_PARSING_FAILURE
# Model Output: {
#   "CC38960494.pdf": {
#     "ERC": 1,
#     "Fecha_Dx_ERC": null
#   }
# }
# Model Output: {"CC6494067.pdf": {"ERC": 1, "Fecha_Dx_ERC": null}}
# Registro: 20 de 100
# Model Output: {"CC4589307.pdf": {"ERC": 0, "Fecha_Dx_ERC": null}}
# Model Output: {"CC29298149.pdf": {"ERC": 0, "Fecha_Dx_ERC": null}}
# Model Output: {"CC14986444.pdf": {"ERCDiagnosis": 0}}
# ⚠️  Parse failed: Failed to parse ArgumentResponse from completion {"CC14986444.pdf": {"ERCDiagnosis": 0}}. Got: 1 validation error for ArgumentResponse
# `CC14986444.pdf`.ERC
#   Field required [type=missing, input_value={'ERCDiagnosis': 0}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/OUTPUT_PARSING_FAILURE
# Model Output: {"CC6279058.pdf": {"ERC": 1, "Fecha_Dx_ERC": null}}
# Model Output: {"CC24268447.pdf": {"ERC": 0, "Fecha_Dx_ERC": null}}
# Model Output: {"CC26390865.pdf": {"ERC": 1, "Fecha_Dx_ERC": null}}
# Model Output: {"CC14994724.pdf": {"ERC": 0, "Fecha_Dx_ERC": null}}
# Model Output: {"CC6256890.pdf": {"ERC": 1, "Fecha_Dx_ERC": null}}
# Model Output: {"CC31239230.pdf": {"ERC": 0, "Fecha_Dx_ERC": null}}
# Model Output: {"CC25264743.pdf": {"ERC": 0, "Fecha_Dx_ERC": null}}
# Registro: 30 de 100
# Model Output: {"CC6086951.pdf": {"ERC": 0, "Fecha_Dx_ERC": null}}
# Model Output: {"CC31889024.pdf": {"ERC": 1, "Fecha_Dx_ERC": null}}
# Model Output: {"CC31236581.pdf": {"ERC": 0, "Fecha_Dx_ERC": null}}
# Model Output: {"CC66975500.pdf": {"ERC": 1, "Fecha_Dx_ERC": null}}
# Model Output: {"CC29804260.pdf": {"ERC": 1, "Fecha_Dx_ERC": null}}
# Model Output: {"CC27322738.pdf": {"ERCDiagnosis": 0, "Fecha_Dx_ERC": null}}
# ⚠️  Parse failed: Failed to parse ArgumentResponse from completion {"CC27322738.pdf": {"ERCDiagnosis": 0, "Fecha_Dx_ERC": null}}. Got: 1 validation error for ArgumentResponse
# `CC27322738.pdf`.ERC
#   Field required [type=missing, input_value={'ERCDiagnosis': 0, 'Fecha_Dx_ERC': None}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/OUTPUT_PARSING_FAILURE
# Model Output: {"CC66846793.pdf": {"ERC": 0, "Fecha_Dx_ERC": null}}
# Model Output: {"CC1232518.pdf": {"ERC": 0, "Fecha_Dx_ERC": null}}
# Model Output: {"CC31988364.pdf": {"ERC": 0, "Fecha_Dx_ERC": null}}
# Model Output: {"CC38433864.pdf": {"ERC": 0, "Fecha_Dx_ERC": null}}
# Registro: 40 de 100
# Model Output: {"CC41377296.pdf": {"ERC": 0, "Fecha_Dx_ERC": null}}
# Model Output: {"CC29061348.pdf": {"ERC": 0, "Fecha_Dx_ERC": null}}
# Model Output: {"CC6085419.pdf": {"ERC": 0, "Fecha_Dx_ERC": null}}
# Model Output: {"CC14438430.pdf": {"ERC": 0, "Fecha_Dx_ERC": null}}
# Model Output: {"CC27508135.pdf": {"ERC": 0, "Fecha_Dx_ERC": null}}
# Model Output: {"890268": {"$defs": {"ERCDiagnosis": {"properties": {"ERC": 13, "Fecha_Dx_ERC": null}, "required": ["ERC"], "type": "object"}}, "additionalProperties": "{$defs/ERCDiagnosis}"}, "required": [], "type": "object"}}
# ⚠️  Parse failed: Failed to parse ArgumentResponse from completion null. Got: 1 validation error for ArgumentResponse
#   Input should be a valid dictionary [type=dict_type, input_value=None, input_type=NoneType]
#     For further information visit https://errors.pydantic.dev/2.11/v/dict_type
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/OUTPUT_PARSING_FAILURE

# %% [markdown]
# ### Hipertensión Arterial

# %%
from datetime import datetime
from typing import Dict, Optional
from pydantic import BaseModel, Field, RootModel 

class HTADiagnosis(BaseModel):
    HTA: int
    Fecha_Dx_HTA: Optional[datetime] = Field(None, description="Date of HTA diagnosis")

# Root model whose single value is Dict[str, Diagnosis]
class ArgumentResponse(RootModel[Dict[str, HTADiagnosis]]):
    pass

pydantic_parser = PydanticOutputParser(pydantic_object=ArgumentResponse)

def extract_json_block(text: str) -> str:
    """Extract a JSON object from LLM output (robust to markdown and extra text)."""
    match = re.search(r"\{.*\}", text, re.DOTALL)
    if not match:
        raise ValueError(f"Could not find a JSON object in output:\n{text}")
    return match.group(0)

example_json = {
    "38945530.pdf": {
        "HTA": 0,
        "Fecha_Dx_HTA": "2019-05-21"
    }
}


def extract_arguments_json(text: str, condition: str) -> ArgumentResponse:
    format_instructions = pydantic_parser.get_format_instructions()
    prompt = PromptTemplate(
        template=(
            "You are an medical diagnosis assistant reading patient medical histories in pdfs.\n\n"
            "I want to extract if the patient has {condition} (HTA = 1 if not HTA=0) and its date of diagnosis (YYYY-MM-DD) if present.\n\n"
            "Extract pdf name, diagnosis and date ONLY in regard to this specific medical condition: \"{condition}\" directly from the text below.\n\n"
            "Text:\n\"\"\"\n{text}\n\"\"\""
            "Return **exactly one JSON object** whose keys are the PDF file names and whose values follow this format: "
            "{format_instructions}"
            "Do not include markdown (```), explanations, or JSON schemas. Just output the raw JSON object without fields like properties or required."
        ),
        input_variables=["text", "condition"],
        partial_variables={"format_instructions": format_instructions},
    )

    final_prompt = prompt.format_prompt(text=text, condition=condition).to_string()

    payload = {
        "model": "qwen2.5:3b",
        "prompt": final_prompt,
        "temperature": 0,
        "stream": False
    }

    response = requests.post("http://localhost:11434/api/generate", json=payload)
    if response.status_code != 200:
        raise Exception(f"Ollama error: {response.text}")

    raw_output = response.json()["response"]

    print("Model Output:", raw_output)
        # ---- try to parse; on error just return None
    try:
        return pydantic_parser.parse(raw_output)
    
    except OutputParserException as err:
        print("⚠️  Parse failed:", err)
        return None

import json
from datetime import datetime

def write_ndjson(pdf_name: str, diag_dict: dict, path: str = "diagnoses_hipertensionarterial.txt"):
    # Convert any datetime objects to ISO strings so json.dumps can handle them
    for k, v in diag_dict.items():
        if isinstance(v, datetime):
            diag_dict[k] = v.date().isoformat()   # "YYYY-MM-DD"

    record = {pdf_name: diag_dict}               # wrap with the filename key
    line = json.dumps(record, ensure_ascii=False)

    # Append to the file, adding a newline
    with open(path, "a", encoding="utf-8") as f:
        f.write(line + "\n")

# %%
df[df['Patologia']=='Hipertensión Arterial']['Tipo_Ocurrencia'].unique()
# Out:
# array(['Hipertension', 'Hipertension esencial', 'Hipertension arterial',
#        'I10X', 'HTA', 'Hipertensión', 'Hipertensión arterial'],
#       dtype=object)

# %%
from collections import defaultdict
import difflib                           

pdf_to_snippets: dict[str, list[str]] = defaultdict(list)

for key in x_test.keys():               
    pdf_name, _ = key.rsplit("_", 1)
    if x_test[key]['Patologia'] == 'Hipertensión Arterial':   
        pdf_to_snippets[pdf_name].append(x_test[key]["Contexto_recuperado"])

pdf_to_text: dict[str, str] = {
    pdf: "\n".join(deduplicate(snips))
    for pdf, snips in pdf_to_snippets.items()
}

print("Number of PDFs with HTA snippets:", len(pdf_to_text))


condition = "HiperTension Arterial (HTA) or High Blood Pressure or Hipertension or I10X"
out_path  = "diagnoses_HTA_qwen2-5_3b_wholetext.txt"

for i, (pdf_name, merged_text) in enumerate(pdf_to_text.items(), start=1):
    if i % 10 == 0:
        print(f"Registro: {i} de {len(pdf_to_text)}")

    prompt_text = f"pdf name: {pdf_name} \n text: {merged_text}"
    result = extract_arguments_json(prompt_text, condition)

    if result is None or len(result.root)==0:  
        continue

    diag = next(iter(result.root.values()))         
    write_ndjson(
        pdf_name,                                  
        {"HTA": diag.HTA, "Fecha_Dx_HTA": diag.Fecha_Dx_HTA},
        path=out_path,
    )
# Out:
# Number of PDFs with HTA snippets: 98
# Model Output: {"CC38990979.pdf": {"HTA": 1, "Fecha_Dx_HTA": null}}
# Model Output: {"CC4302926.pdf": {"HTA": 0, "Fecha_Dx_HTA": null}}
# Model Output: {"CC21376431.pdf": {"I10X": 1, "Fecha_Dx_HTA": null}}
# ⚠️  Parse failed: Failed to parse ArgumentResponse from completion {"CC21376431.pdf": {"I10X": 1, "Fecha_Dx_HTA": null}}. Got: 1 validation error for ArgumentResponse
# `CC21376431.pdf`.HTA
#   Field required [type=missing, input_value={'I10X': 1, 'Fecha_Dx_HTA': None}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/OUTPUT_PARSING_FAILURE
# Model Output: {"CC2392028.pdf": {"HTA": 1, "Fecha_Dx_HTA": null}}
# Model Output: {"CC66811116.pdf": {"HTA": 0, "Fecha_Dx_HTA": null}}
# Model Output: {"CC27293711.pdf": {"HTA": 0, "Fecha_Dx_HTA": null}}
# Model Output: {"CC4640234.pdf": {"HTA": 0, "Fecha_Dx_HTA": null}}
# Model Output: {"CC94281430.pdf": {"HTA": 0, "Fecha_Dx_HTA": null}}
# Model Output: {"CC31260873.pdf": {"HTA": 0, "Fecha_Dx_HTA": null}}
# Registro: 10 de 98
# Model Output: {"CC38440317.pdf": {"HTA": 0, "Fecha_Dx_HTA": null}}
# Model Output: {"CC29802554.pdf": {"HTA": 1, "Fecha_Dx_HTA": null}}
# Model Output: {"CC29325288.pdf": {"HTA": 0, "Fecha_Dx_HTA": null}}
# Model Output: {"CC31252756.pdf": {"HTA": 0, "Fecha_Dx_HTA": null}}
# Model Output: {"CC29049220.pdf": {"HTA": 1, "Fecha_Dx_HTA": null}}
# Model Output: {"CC41306363.pdf": {"HTA": 0, "Fecha_Dx_HTA": null}}
# Model Output: {"CC2550458.pdf": {"HTA": 1, "Fecha_Dx_HTA": null}}
# Model Output: {"CC31219907.pdf": {"HTA": 0, "Fecha_Dx_HTA": null}}
# Model Output: {"CC38960494.pdf": {"HTA": 0, "Fecha_Dx_HTA": null}}
# Model Output: {"CC6494067.pdf": {"HTA": 1, "Fecha_Dx_HTA": null}}
# Registro: 20 de 98
# Model Output: {"CC29298149.pdf": {"HTA": 0, "Fecha_Dx_HTA": null}}
# Model Output: {"CC14986444.pdf": {"HTA": 0, "Fecha_Dx_HTA": null}}
# Model Output: {"CC6279058.pdf": {"HTA": 0, "Fecha_Dx_HTA": null}}
# Model Output: {"CC24268447.pdf": {"HTA": 0, "Fecha_Dx_HTA": null}}
# Model Output: {"CC26390865.pdf": {"HTA": 0, "Fecha_Dx_HTA": null}}
# Model Output: {"CC14994724.pdf": {"HTA": 0, "Fecha_Dx_HTA": null}, "CONSULTA26092022.pdf": {"HTA": 0, "Fecha_Dx_HTA": null}}
# Model Output: {"CC6256890.pdf": {"HTA": 0, "Fecha_Dx_HTA": null}}
# Model Output: {"CC31239230.pdf": {"HTA": 0, "Fecha_Dx_HTA": null}}
# Model Output: {"CC25264743.pdf": {"HTA": 0, "Fecha_Dx_HTA": null}}
# Model Output: {"CC6086951.pdf": {"HTA": 0, "Fecha_Dx_HTA": null}}
# Registro: 30 de 98
# Model Output: {"CC31889024.pdf": {"HTA": 0, "Fecha_Dx_HTA": null}}
# Model Output: {"CC31236581.pdf": {"HTA": 0, "Fecha_Dx_HTA": null}}
# Model Output: {"CC66975500.pdf": {"HTA": 1, "Fecha_Dx_HTA": null}}
# Model Output: {"CC29804260.pdf": {"HTA": 1, "Fecha_Dx_HTA": null}}
# Model Output: {"CC27322738.pdf": {"HTA": 1, "Fecha_Dx_HTA": null}}
# Model Output: {"CC66846793.pdf": {"HTA": 0, "Fecha_Dx_HTA": null}, "I10X HIPERTENSION ESENCIAL PRIMARIA": {"HTA": 1, "Fecha_Dx_HTA": "2019-08-31"}, "I698 SECUELAS DE OTRAS ENFERMEDADES CEREBROVASCULAR ES Y DE LAS NO ESPECIFICADAS": {"HTA": 0, "Fecha_Dx_HTA": null}}
# Model Output: {"CC1232518.pdf": {"HTA": 0, "Fecha_Dx_HTA": null}}
# Model Output: {"CC31988364.pdf": {"HTA": 0, "Fecha_Dx_HTA": null}}
# Model Output: {"CC38433864.pdf": {"HTA": 0, "Fecha_Dx_HTA": null}}
# Model Output: {"CC41377296.pdf": {"HTA": 0, "Fecha_Dx_HTA": null}}
# Registro: 40 de 98
# Model Output: {"CC29061348.pdf": {"HTA": 0, "Fecha_Dx_HTA": null}}
# Model Output: {"CC6085419.pdf": {"HTA": 0, "Fecha_Dx_HTA": null}}
# Model Output: {"CC14438430.pdf": {"HTA": 0, "Fecha_Dx_HTA": null}}
# Model Output: {"CC27508135.pdf": {"HTA": 0, "Fecha_Dx_HTA": null}}
# Model Output: {"CC31856748.pdf": {"HTA": 0, "Fecha_Dx_HTA": null}}
# Model Output: {"CC34532892.pdf": {"HTA": 0, "Fecha_Dx_HTA": null}}
# Model Output: {"CC16679174.pdf": {"HTA": 0, "Fecha_Dx_HTA": null}}
# Model Output: {"CC31253879.pdf": {"HTA": 0, "Fecha_Dx_HTA": null}}
# Model Output: {"CC14870542.pdf": {"HTA": 0, "Fecha_Dx_HTA": null}}
# Model Output: {"CC29768571.pdf": {"HTA": 0, "Fecha_Dx_HTA": null}}
# Registro: 50 de 98
# Model Output: {"CC29938688.pdf": {"HTA": 0, "Fecha_Dx_HTA": null}}
# Model Output: {"CC29408150.pdf": {"HTA": 0, "Fecha_Dx_HTA": null}}
# Model Output: {"CC29013852.pdf": {"HTA": 1, "Fecha_Dx_HTA": null}}
# Model Output: {"CC25668921.pdf": {"HTA": 0, "Fecha_Dx_HTA": null}}
# Model Output: {"CC38431259.pdf": {"HTA": 0, "Fecha_Dx_HTA": null}}
# Model Output: {"CC2578511.pdf": {"HTA": 0, "Fecha_Dx_HTA": null}}
# Model Output: {"CC24117336.pdf": {"HTA": 0, "Fecha_Dx_HTA": null}}
# Model Output: {"CC16618290.pdf": {"HTA": 0, "Fecha_Dx_HTA": null}}
# Model Output: {"CC7425344.pdf": {"HTA": 0, "Fecha_Dx_HTA": null}}
# Model Output: {"CC29420074.pdf": {"HTA": 1, "Fecha_Dx_HTA": null}}
# Registro: 60 de 98
# Model Output: {"CC29218414.pdf": {"HTA": 0, "Fecha_Dx_HTA": null}}
# Model Output: {"CC38994135.pdf": {"HTA": 0, "Fecha_Dx_HTA": null}}
# Model Output: {"I10X-HIPERTENSION-ESENCIAL-PRIMARIA": {"HTA": 27032019, "Fecha_Dx_HTA": null}, "N189-INSUFICIENCIA-RENAL-CRONICA-NO-ESPECIFICADA": {"HTA": 27032019, "Fecha_Dx_HTA": null}}
# Model Output: {"CC1382634.pdf": {"HTA": 0, "Fecha_Dx_HTA": null}}
# Model Output: {"CC14441265.pdf": {"HTA": 0, "Fecha_Dx_HTA": null}}
# Model Output: {"CC1111789238.pdf": {"HTA": 0, "Fecha_Dx_HTA": null}, "N219.pdf": {"HTA": 1, "Fecha_Dx_HTA": "2021-06-04T13:07"}, "N189.pdf": {"HTA": 1, "Fecha_Dx_HTA": "2023-04-04T13:07"}}
# Model Output: {"CC29569552.pdf": {"HTA": 0, "Fecha_Dx_HTA": null}}
# Model Output: {"CC31297039.pdf": {"HTA": 0, "Fecha_Dx_HTA": null}}
# Model Output: {"CC28902606.pdf": {"HTA": 1, "Fecha_Dx_HTA": null}, "N45376294.pdf": {"HTA": 1, "Fecha_Dx_HTA": "2019-09-27T13:02"}}
# Model Output: {"CC29071098.pdf": {"HTA": 0, "Fecha_Dx_HTA": null}}
# Registro: 70 de 98
# Model Output: {"CC31234612.pdf": {"HTA": 0, "Fecha_Dx_HTA": null}}
# Model Output: {"CC14981373.pdf": {"HTA": 0, "Fecha_Dx_HTA": null}, "N1256789.pdf": {"HTA": 1, "Fecha_Dx_HTA": "2019-04-30"}}
# Model Output: {"CC34534214.pdf": {"HTA": 0, "Fecha_Dx_HTA": null}}
# Model Output: {"CC31215428.pdf": {"HTA": 0, "Fecha_Dx_HTA": null}}
# Model Output: {"CC6052364.pdf": {"HTA": 1, "Fecha_Dx_HTA": null}}
# Model Output: {"CC334534214.pdf": {"HTA": 0, "Fecha_Dx_HTA": null}}
# Model Output: {"CC29057853.pdf": {"HTA": 1, "Fecha_Dx_HTA": null}}
# Model Output: {"CC16583376.pdf": {"HTA": 0, "Fecha_Dx_HTA": null}}
# Model Output: {"CC29015033.pdf": {"HTA": 1, "Fecha_Dx_HTA": null}}
# Model Output: {"CC29569898.pdf": {"HTA": 0, "Fecha_Dx_HTA": null}}
# Registro: 80 de 98
# Model Output: {"CC28945543.pdf": {"HTA": 0, "Fecha_Dx_HTA": null}}
# Model Output: {"CC16693057.pdf": {"HTA": 0, "Fecha_Dx_HTA": null}, "CC18247328.pdf": {"HTA": 0, "Fecha_Dx_HTA": null}, "CC21675348.pdf": {"HTA": 0, "Fecha_Dx_HTA": null}}
# Model Output: {"CC6556408.pdf": {"HTA": 1, "Fecha_Dx_HTA": null}}
# Model Output: {"CC16635483.pdf": {"HTA": 0, "Fecha_Dx_HTA": null}}
# Model Output: {"CC155193.pdf": {"HTA": 0, "Fecha_Dx_HTA": null}}
# Model Output: {"CC31883054.pdf": {"I10X": 1, "Fecha_Dx_HTA": null}}
# ⚠️  Parse failed: Failed to parse ArgumentResponse from completion {"CC31883054.pdf": {"I10X": 1, "Fecha_Dx_HTA": null}}. Got: 1 validation error for ArgumentResponse
# `CC31883054.pdf`.HTA
#   Field required [type=missing, input_value={'I10X': 1, 'Fecha_Dx_HTA': None}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/OUTPUT_PARSING_FAILURE
# Model Output: {"CC33123121.pdf": {"I10X HIPERTENSION ESENCIAL PRIMARIA": {"HTA": 1, "Fecha_Dx_HTA": null}}}
# ⚠️  Parse failed: Failed to parse ArgumentResponse from completion {"CC33123121.pdf": {"I10X HIPERTENSION ESENCIAL PRIMARIA": {"HTA": 1, "Fecha_Dx_HTA": null}}}. Got: 1 validation error for ArgumentResponse
# `CC33123121.pdf`.HTA
#   Field required [type=missing, input_value={'I10X HIPERTENSION ESENC..., 'Fecha_Dx_HTA': None}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/OUTPUT_PARSING_FAILURE
# Model Output: {"CC1114731025.pdf": {"HTA": 1, "Fecha_Dx_HTA": "2020-10-08"}}
# Model Output: {"CC10550360.pdf": {"HTA": 0, "Fecha_Dx_HTA": null}}
# Model Output: {"CC3288014.pdf": {"HTA": 0, "Fecha_Dx_HTA": null}}
# Registro: 90 de 98
# Model Output: {"CC29398754.pdf": {"HTA": 1, "Fecha_Dx_HTA": null}}
# Model Output: {"CC29363141.pdf": {"HTA": 0, "Fecha_Dx_HTA": null}}
# Model Output: {"CC24444308.pdf": {"HTA": 0, "Fecha_Dx_HTA": null}}
# Model Output: {"CC31242769.pdf": {"HTA": 0, "Fecha_Dx_HTA": null}}
# Model Output: {"CC38968684.pdf": {"HTA": 0, "Fecha_Dx_HTA": null}}
# Model Output: {"CC25711801.pdf": {"HTA": 0, "Fecha_Dx_HTA": null}}
# Model Output: {"CC29141113.pdf": {"HTA": 0, "Fecha_Dx_HTA": null}, "CC29185767.pdf": {"HTA": 1, "Fecha_Dx_HTA": "2019-03-06T00:00:00Z"}}
# Model Output: {"CC29210651.pdf": {"I10X": 1, "Fecha_Dx_HTA": null}}
# ⚠️  Parse failed: Failed to parse ArgumentResponse from completion {"CC29210651.pdf": {"I10X": 1, "Fecha_Dx_HTA": null}}. Got: 1 validation error for ArgumentResponse
# `CC29210651.pdf`.HTA
#   Field required [type=missing, input_value={'I10X': 1, 'Fecha_Dx_HTA': None}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/OUTPUT_PARSING_FAILURE
# Model Output: {"CC6082929.pdf": {"HTA": 1, "Fecha_Dx_HTA": null}}

# %% [markdown]
# ## Evaluacion resultados

# %% [markdown]
# ### Diabetes

# %%
import json, numpy as np, pandas as pd
from pathlib import Path
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score

# ───────────────────────────── 1. read predictions ────────────────────────────
txt_path = Path("../outputs/diagnoses_diabetes_qwen2-5_3b_wholetext.txt")

records = []
with txt_path.open(encoding="utf-8") as f:
    for line in f:
        if not line.strip():
            continue
        outer = json.loads(line)
        full_key, inner = next(iter(outer.items()))
        records.append(
            {
                "Nombre_PDF"   : full_key,
                "DM_pred"     : inner["DM"],
                "Fecha_Dx_DM_pred": inner["Fecha_Dx_DM"],
            }
        )

df_pred = pd.DataFrame(records)
df_pred["DM_pred"] = np.where(df_pred["DM_pred"] > 1, 0, df_pred["DM_pred"])
df_pred["Fecha_Dx_DM_pred"] = pd.to_datetime(df_pred["Fecha_Dx_DM_pred"])

# ───────────────────────────── 2. merge with ground truth ─────────────────────
df_metrics = (
    df_info
    .rename(columns={"DM": "DM_gt", "Fecha_Dx_DM": "Fecha_Dx_DM_gt"})
    .merge(df_pred, on="Nombre_PDF", how="inner")
)

# ───────────────────────────── 3. helper to collect metrics ───────────────────
def metric_table(y_true, y_pred, name):
    y_true = y_true.astype(int)
    y_pred = y_pred.astype(int)
    return pd.DataFrame([{
        "Metric set": name,
        "Accuracy"  : accuracy_score (y_true, y_pred),
        "Recall"    : recall_score   (y_true, y_pred, zero_division=0),
        "Precision" : precision_score(y_true, y_pred, zero_division=0),
        "F1"        : f1_score       (y_true, y_pred, zero_division=0),
    }])

results = []
results.append(metric_table(df_metrics["DM_gt"], df_metrics["DM_pred"], "DM diagnosis"))

# ───────────────────────────── 4. date-match that works for list or scalar ────
def date_match(row) -> int:
    gt   = row["Fecha_Dx_DM_gt"]      # NaT or Timestamp
    pred = row["Fecha_Dx_DM_pred"]    # NaT, Timestamp, or list

    # case 1: both “null”
    if pd.isna(gt):
        return int(pd.isna(pred) or (isinstance(pred, list) and len(pred) == 0))

    # ensure pred is iterable
    if not isinstance(pred, list):
        pred = [pred]
        return int(gt in pred)

df_metrics["date_ok"] = df_metrics.apply(date_match, axis=1)
df_metrics["date_ok_gt"]= np.where(df_metrics["Fecha_Dx_DM_gt"].isna(), 0, 1)
results.append(metric_table(df_metrics["date_ok_gt"], df_metrics["date_ok"], "Diagnosis DM date"))

# ───────────────────────────── 5. show nicely ────────────────────────────────
metrics_df_DM = pd.concat(results, ignore_index=True).round(3)

n_total = len(df_metrics)
n_pos   = int(df_metrics["DM_gt"].sum())
print(f"Evaluado sobre {n_total} historias médicas y {n_pos} pacientes con DM.")

display(
    metrics_df_DM.style
        .format("{:.3f}", subset=["Accuracy", "Recall", "Precision", "F1"])
        .set_properties(**{"text-align": "center"})
        .set_table_styles(
            [{"selector": "th", "props": [("text-align", "center")]}]
        )
)
# Out:
# Evaluado sobre 82 historias médicas y 38 pacientes con DM.
# <style type="text/css">
# #T_7b2f3 th {
#   text-align: center;
# }
# #T_7b2f3_row0_col0, #T_7b2f3_row0_col1, #T_7b2f3_row0_col2, #T_7b2f3_row0_col3, #T_7b2f3_row0_col4, #T_7b2f3_row1_col0, #T_7b2f3_row1_col1, #T_7b2f3_row1_col2, #T_7b2f3_row1_col3, #T_7b2f3_row1_col4 {
#   text-align: center;
# }
# </style>
# <table id="T_7b2f3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7b2f3_level0_col0" class="col_heading level0 col0" >Metric set</th>
#       <th id="T_7b2f3_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_7b2f3_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_7b2f3_level0_col3" class="col_heading level0 col3" >Precision</th>
#       <th id="T_7b2f3_level0_col4" class="col_heading level0 col4" >F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7b2f3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7b2f3_row0_col0" class="data row0 col0" >DM diagnosis</td>
#       <td id="T_7b2f3_row0_col1" class="data row0 col1" >0.634</td>
#       <td id="T_7b2f3_row0_col2" class="data row0 col2" >0.289</td>
#       <td id="T_7b2f3_row0_col3" class="data row0 col3" >0.786</td>
#       <td id="T_7b2f3_row0_col4" class="data row0 col4" >0.423</td>
#     </tr>
#     <tr>
#       <th id="T_7b2f3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7b2f3_row1_col0" class="data row1 col0" >Diagnosis DM date</td>
#       <td id="T_7b2f3_row1_col1" class="data row1 col1" >0.012</td>
#       <td id="T_7b2f3_row1_col2" class="data row1 col2" >0.028</td>
#       <td id="T_7b2f3_row1_col3" class="data row1 col3" >0.021</td>
#       <td id="T_7b2f3_row1_col4" class="data row1 col4" >0.024</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Enfermedad Renal Cronica

# %%
import json, numpy as np, pandas as pd
from pathlib import Path
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score

# ───────────────────────────── 1. read predictions ────────────────────────────
txt_path = Path("../outputs/diagnoses_ERC_qwen2-5_3b_wholetext.txt")

records = []
with txt_path.open(encoding="utf-8") as f:
    for line in f:
        if not line.strip():
            continue
        outer = json.loads(line)
        full_key, inner = next(iter(outer.items()))
        records.append(
            {
                "Nombre_PDF"   : full_key,
                "ERC_pred"     : inner["ERC"],
                "Fecha_Dx_ERC_pred": inner["Fecha_Dx_ERC"],
            }
        )

df_pred = pd.DataFrame(records)
df_pred["ERC_pred"] = np.where(df_pred["ERC_pred"] > 1, 0, df_pred["ERC_pred"])
df_pred["Fecha_Dx_ERC_pred"] = pd.to_datetime(df_pred["Fecha_Dx_ERC_pred"])

# ───────────────────────────── 2. merge with ground truth ─────────────────────
df_metrics = (
    df_info
    .rename(columns={"ERC": "ERC_gt", "Fecha_Dx_ERC": "Fecha_Dx_ERC_gt"})
    .merge(df_pred, on="Nombre_PDF", how="inner")
)

# ───────────────────────────── 3. helper to collect metrics ───────────────────
def metric_table(y_true, y_pred, name):
    y_true = y_true.astype(int)
    y_pred = y_pred.astype(int)
    return pd.DataFrame([{
        "Metric set": name,
        "Accuracy"  : accuracy_score (y_true, y_pred),
        "Recall"    : recall_score   (y_true, y_pred, zero_division=0),
        "Precision" : precision_score(y_true, y_pred, zero_division=0),
        "F1"        : f1_score       (y_true, y_pred, zero_division=0),
    }])

results = []
results.append(metric_table(df_metrics["ERC_gt"], df_metrics["ERC_pred"], "ERC diagnosis"))

# ───────────────────────────── 4. date-match that works for list or scalar ────
def date_match(row) -> int:
    gt   = row["Fecha_Dx_ERC_gt"]      # NaT or Timestamp
    pred = row["Fecha_Dx_ERC_pred"]    # NaT, Timestamp, or list

    # case 1: both “null”
    if pd.isna(gt):
        return int(pd.isna(pred) or (isinstance(pred, list) and len(pred) == 0))

    # ensure pred is iterable
    if not isinstance(pred, list):
        pred = [pred]
        return int(gt in pred)

df_metrics["date_ok"] = df_metrics.apply(date_match, axis=1)
df_metrics["date_ok_gt"]= np.where(df_metrics["Fecha_Dx_ERC_gt"].isna(), 0, 1)
results.append(metric_table(df_metrics["date_ok_gt"], df_metrics["date_ok"], "Diagnosis ERC date"))

# ───────────────────────────── 5. show nicely ────────────────────────────────
metrics_df_ERC = pd.concat(results, ignore_index=True).round(3)

n_total = len(df_metrics)
n_pos   = int(df_metrics["ERC_gt"].sum())
print(f"Evaluado sobre {n_total} historias médicas y {n_pos} pacientes con ERC.")

display(
    metrics_df_ERC.style
        .format("{:.3f}", subset=["Accuracy", "Recall", "Precision", "F1"])
        .set_properties(**{"text-align": "center"})
        .set_table_styles(
            [{"selector": "th", "props": [("text-align", "center")]}]
        )
)
# Out:
# Evaluado sobre 80 historias médicas y 78 pacientes con ERC.
# <style type="text/css">
# #T_e34ff th {
#   text-align: center;
# }
# #T_e34ff_row0_col0, #T_e34ff_row0_col1, #T_e34ff_row0_col2, #T_e34ff_row0_col3, #T_e34ff_row0_col4, #T_e34ff_row1_col0, #T_e34ff_row1_col1, #T_e34ff_row1_col2, #T_e34ff_row1_col3, #T_e34ff_row1_col4 {
#   text-align: center;
# }
# </style>
# <table id="T_e34ff">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e34ff_level0_col0" class="col_heading level0 col0" >Metric set</th>
#       <th id="T_e34ff_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_e34ff_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_e34ff_level0_col3" class="col_heading level0 col3" >Precision</th>
#       <th id="T_e34ff_level0_col4" class="col_heading level0 col4" >F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e34ff_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e34ff_row0_col0" class="data row0 col0" >ERC diagnosis</td>
#       <td id="T_e34ff_row0_col1" class="data row0 col1" >0.338</td>
#       <td id="T_e34ff_row0_col2" class="data row0 col2" >0.321</td>
#       <td id="T_e34ff_row0_col3" class="data row0 col3" >1.000</td>
#       <td id="T_e34ff_row0_col4" class="data row0 col4" >0.485</td>
#     </tr>
#     <tr>
#       <th id="T_e34ff_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e34ff_row1_col0" class="data row1 col0" >Diagnosis ERC date</td>
#       <td id="T_e34ff_row1_col1" class="data row1 col1" >0.000</td>
#       <td id="T_e34ff_row1_col2" class="data row1 col2" >0.000</td>
#       <td id="T_e34ff_row1_col3" class="data row1 col3" >0.000</td>
#       <td id="T_e34ff_row1_col4" class="data row1 col4" >0.000</td>
#     </tr>
#   </tbody>
# </table>

# %%
import json, numpy as np, pandas as pd
from pathlib import Path
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score

# ───────────────────────────── 1. read predictions ────────────────────────────
txt_path = Path("../outputs/diagnoses_HTA_qwen2-5_3b_wholetext.txt")

records = []
with txt_path.open(encoding="utf-8") as f:
    for line in f:
        if not line.strip():
            continue
        outer = json.loads(line)
        full_key, inner = next(iter(outer.items()))
        records.append(
            {
                "Nombre_PDF"   : full_key,
                "HTA_pred"     : inner["HTA"],
                "Fecha_Dx_HTA_pred": inner["Fecha_Dx_HTA"],
            }
        )

df_pred = pd.DataFrame(records)
df_pred["HTA_pred"] = np.where(df_pred["HTA_pred"] > 1, 0, df_pred["HTA_pred"])
df_pred["Fecha_Dx_HTA_pred"] = pd.to_datetime(df_pred["Fecha_Dx_HTA_pred"])

# ───────────────────────────── 2. merge with ground truth ─────────────────────
df_metrics = (
    df_info
    .rename(columns={"HTA": "HTA_gt", "Fecha_Dx_HTA": "Fecha_Dx_HTA_gt"})
    .merge(df_pred, on="Nombre_PDF", how="inner")
)

# ───────────────────────────── 3. helper to collect metrics ───────────────────
def metric_table(y_true, y_pred, name):
    y_true = y_true.astype(int)
    y_pred = y_pred.astype(int)
    return pd.DataFrame([{
        "Metric set": name,
        "Accuracy"  : accuracy_score (y_true, y_pred),
        "Recall"    : recall_score   (y_true, y_pred, zero_division=0),
        "Precision" : precision_score(y_true, y_pred, zero_division=0),
        "F1"        : f1_score       (y_true, y_pred, zero_division=0),
    }])

results = []
results.append(metric_table(df_metrics["HTA_gt"], df_metrics["HTA_pred"], "HTA diagnosis"))

# ───────────────────────────── 4. date-match that works for list or scalar ────
def date_match(row) -> int:
    gt   = row["Fecha_Dx_HTA_gt"]      # NaT or Timestamp
    pred = row["Fecha_Dx_HTA_pred"]    # NaT, Timestamp, or list

    # case 1: both “null”
    if pd.isna(gt):
        return int(pd.isna(pred) or (isinstance(pred, list) and len(pred) == 0))

    # ensure pred is iterable
    if not isinstance(pred, list):
        pred = [pred]
        return int(gt in pred)

df_metrics["date_ok"] = df_metrics.apply(date_match, axis=1)
df_metrics["date_ok_gt"]= np.where(df_metrics["Fecha_Dx_HTA_gt"].isna(), 0, 1)
results.append(metric_table(df_metrics["date_ok_gt"], df_metrics["date_ok"], "Diagnosis HTA date"))

# ───────────────────────────── 5. show nicely ────────────────────────────────
metrics_df_HTA = pd.concat(results, ignore_index=True).round(3)

n_total = len(df_metrics)
n_pos   = int(df_metrics["HTA_gt"].sum())
print(f"Evaluado sobre {n_total} historias médicas y {n_pos} pacientes con HTA.")

display(
    metrics_df_HTA.style
        .format("{:.3f}", subset=["Accuracy", "Recall", "Precision", "F1"])
        .set_properties(**{"text-align": "center"})
        .set_table_styles(
            [{"selector": "th", "props": [("text-align", "center")]}]
        )
)
# Out:
# Evaluado sobre 94 historias médicas y 93 pacientes con HTA.
# <style type="text/css">
# #T_ae825 th {
#   text-align: center;
# }
# #T_ae825_row0_col0, #T_ae825_row0_col1, #T_ae825_row0_col2, #T_ae825_row0_col3, #T_ae825_row0_col4, #T_ae825_row1_col0, #T_ae825_row1_col1, #T_ae825_row1_col2, #T_ae825_row1_col3, #T_ae825_row1_col4 {
#   text-align: center;
# }
# </style>
# <table id="T_ae825">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ae825_level0_col0" class="col_heading level0 col0" >Metric set</th>
#       <th id="T_ae825_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_ae825_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_ae825_level0_col3" class="col_heading level0 col3" >Precision</th>
#       <th id="T_ae825_level0_col4" class="col_heading level0 col4" >F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ae825_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ae825_row0_col0" class="data row0 col0" >HTA diagnosis</td>
#       <td id="T_ae825_row0_col1" class="data row0 col1" >0.213</td>
#       <td id="T_ae825_row0_col2" class="data row0 col2" >0.204</td>
#       <td id="T_ae825_row0_col3" class="data row0 col3" >1.000</td>
#       <td id="T_ae825_row0_col4" class="data row0 col4" >0.339</td>
#     </tr>
#     <tr>
#       <th id="T_ae825_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ae825_row1_col0" class="data row1 col0" >Diagnosis HTA date</td>
#       <td id="T_ae825_row1_col1" class="data row1 col1" >0.011</td>
#       <td id="T_ae825_row1_col2" class="data row1 col2" >0.011</td>
#       <td id="T_ae825_row1_col3" class="data row1 col3" >0.500</td>
#       <td id="T_ae825_row1_col4" class="data row1 col4" >0.021</td>
#     </tr>
#   </tbody>
# </table>

# %%
final_metrics = pd.concat([metrics_df_DM, metrics_df_ERC, metrics_df_HTA], ignore_index=True)
final_metrics


num_cols = ["Accuracy", "Recall", "Precision", "F1"]
totals = final_metrics[num_cols].mean().to_frame().T          # a 1-row DF
totals.insert(0, "Metric set", "Mean")                     # first column


final_metrics_with_avg = (
    pd.concat([final_metrics, totals], ignore_index=True)
      .round(3)                                               # optional rounding
)

final_metrics_with_avg
# Out:
#            Metric set  Accuracy  Recall  Precision     F1
# 0        DM diagnosis     0.634   0.289      0.786  0.423
# 1   Diagnosis DM date     0.012   0.028      0.021  0.024
# 2       ERC diagnosis     0.338   0.321      1.000  0.485
# 3  Diagnosis ERC date     0.000   0.000      0.000  0.000
# 4       HTA diagnosis     0.213   0.204      1.000  0.339
# 5  Diagnosis HTA date     0.011   0.011      0.500  0.021
# 6                Mean     0.201   0.142      0.551  0.215
